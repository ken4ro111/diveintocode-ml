# %% [markdown]
# ## 【問題1】データの取得

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
iris = load_iris()
X = iris.data[: , :]
X = pd.DataFrame(data = X)
X.columns = ["sepal_length" , "sepal_width" , "petal_length" , "petal_width"]

# %%
y = iris.target
y = pd.DataFrame(data = y)
y.columns = ["Species"]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ## 【問題2】データの結合

# %%
df = pd.concat([X , y] , axis = 1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ## 【問題3】データの確認

# %%
#先頭から4番目までのサンプルを表示
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#下から表示　tail
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2

# %%
#各特徴量がどういったものかを見る。（数値データか文字データかなど）
df["Species"].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %%
df0 = df.iloc[:50]
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 2.0 KB

# %%
df1 = df.iloc[50 : 100]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 50 to 99
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 2.0 KB

# %%
df2 = df.iloc[100 : 150]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 100 to 149
# Data columns (total 5 columns):
# sepal_length    50 non-null float64
# sepal_width     50 non-null float64
# petal_length    50 non-null float64
# petal_width     50 non-null float64
# Species         50 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 2.0 KB

# %%
#ラベルごとのサンプル数の合計を出力する。
df0.sum()
# Out:
# sepal_length    250.3
# sepal_width     170.9
# petal_length     73.2
# petal_width      12.2
# Species           0.0
# dtype: float64

# %%
df1.sum()
# Out:
# sepal_length    296.8
# sepal_width     138.5
# petal_length    213.0
# petal_width      66.3
# Species          50.0
# dtype: float64

# %%
df2.sum()
# Out:
# sepal_length    329.4
# sepal_width     148.7
# petal_length    277.6
# petal_width     101.3
# Species         100.0
# dtype: float64

# %%
#特徴量に欠損値があるかを確認する。
#欠損値ゼロ
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64

# %%
#特徴量の平均値と標準偏差、四分位数を一度に表示させる。
df0.describe()
#count: 要素の個数
#mean: 平均値
#std: 標準偏差
#min: 最小値
#max: 最大値
#50%: 中央値（median）
#25%, 75%: 1/4分位数、3/4分位数
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  Species
# count      50.00000    50.000000     50.000000     50.00000     50.0
# mean        5.00600     3.418000      1.464000      0.24400      0.0
# std         0.35249     0.381024      0.173511      0.10721      0.0
# min         4.30000     2.300000      1.000000      0.10000      0.0
# 25%         4.80000     3.125000      1.400000      0.20000      0.0
# 50%         5.00000     3.400000      1.500000      0.20000      0.0
# 75%         5.20000     3.675000      1.575000      0.30000      0.0
# max         5.80000     4.400000      1.900000      0.60000      0.0

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  Species
# count     50.000000    50.000000     50.000000    50.000000     50.0
# mean       5.936000     2.770000      4.260000     1.326000      1.0
# std        0.516171     0.313798      0.469911     0.197753      0.0
# min        4.900000     2.000000      3.000000     1.000000      1.0
# 25%        5.600000     2.525000      4.000000     1.200000      1.0
# 50%        5.900000     2.800000      4.350000     1.300000      1.0
# 75%        6.300000     3.000000      4.600000     1.500000      1.0
# max        7.000000     3.400000      5.100000     1.800000      1.0

# %%
df2.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  Species
# count      50.00000    50.000000     50.000000     50.00000     50.0
# mean        6.58800     2.974000      5.552000      2.02600      2.0
# std         0.63588     0.322497      0.551895      0.27465      0.0
# min         4.90000     2.200000      4.500000      1.40000      2.0
# 25%         6.22500     2.800000      5.100000      1.80000      2.0
# 50%         6.50000     3.000000      5.550000      2.00000      2.0
# 75%         6.90000     3.175000      5.875000      2.30000      2.0
# max         7.90000     3.800000      6.900000      2.50000      2.0

# %% [markdown]
# # 【問題4】irisデータセット自体の調査

# %% [markdown]
# Iris setosa ：アイリスの中で最も丈夫な種の一つ。がく片が非常に小さいため剛毛。 花びらの幅が５〜８センチ、長さは７〜８センチで様々な青の色合いがある。
#
# Iris virgiclor　：草本姓の多年生植物。高さは１０〜８０センチ。 発達した青い花びらは６枚の花弁とがく片がある。
#
# Iris virginica　：２〜４この直立またはアーチ型の明るい緑色の槍形の葉がある。 花びらは幅4cm以上、長さが7cm以上であり3枚のがく片から成る。

# %% [markdown]
# # 【問題5】必要なデータを抽出

# %%
#sepal_widthの列を３つの異なる方法で抽出する
display(df.iloc[: , 1].head())
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
display(df.loc[: , "sepal_width"].head())
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
display(df["sepal_width"].head())
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
display(df.sepal_width.head())
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal_width, dtype: float64

# %%
#50番目から99番目までのデータを抽出する
display(df.iloc[50:100].head())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# 54           6.5          2.8           4.6          1.5        1

# %%
#petal_lengthの列の50番目から99番目までのデータを抽出する
display(df.loc[50:100 , "petal_length"].head())
# Out:
# 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# Name: petal_length, dtype: float64

# %%
display(df.iloc[50:100 , 2].head())
# Out:
# 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# Name: petal_length, dtype: float64

# %%
#petal_widthの値が0.2のデータを抽出する
display(df[ df.petal_width == 0.2].head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
display(df.query("petal_width == 0.2").head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# **loc は 行、列をラベルで指定します。 df.loc[: , sepal_length]
#
# **iloc は 行、列を番号で指定します（先頭が 0） df.iloc[: , 0]

# %% [markdown]
# ## 【問題6】図の作成

# %%
#ラベルごとのサンプル数を円グラフにする（パーセンテージまで表示する）
label_count = df["Species"].value_counts()
iris_label = iris.target_names
plt.title("iris_pie")
plt.pie(label_count ,labels = iris_label , autopct="%1.1f%%" , startangle=90, labeldistance=0.5,
             pctdistance=0.7, wedgeprops={'linewidth': 3, 'edgecolor':"white"},counterclock=False)
plt.show()

# %%
#特徴量を一つずつ選び、箱ひげ図を使ってラベルごとのデータの分布を可視化する
f_names = ["sepal_length" , "sepal_width" , "petal_length" , "petal_width"]
for f_name in f_names:
    plt.boxplot([df[df["Species"] == 0][f_name] , df[df["Species"] == 1][f_name], 
                        df[df["Species"] == 2][f_name]])
    plt.xticks([1,2,3] , iris.target_names)
    plt.title("iris_BOXPLOT  {}".format(f_name))
    
    plt.show()

# %%
#特徴量を一つずつ選び、バイオリン図を使ってラベルごとのデータの分布を可視化する
f_names = ["sepal_length" , "sepal_width" , "petal_length" , "petal_width"]
for f_name in f_names:
    plt.violinplot([df[df["Species"]==0][f_name] , df[df["Species"]==1][f_name],
                             df[df["Species"]==2][f_name]])
    plt.title("iris_VIOLINPLOT  {}".format(f_name))
    plt.xticks([1,2,3] , iris.target_names)
    plt.show()

# %% [markdown]
# バイオリン図には箱ひげ図よりも多くの情報が含まれる。箱ひげ図には平均/中央値と四分位範囲という要約統計量のみが含まれるのに対し、バイオリンプロットにはすべての分布データが含まれる。これはデータ分布がmultimodal（複数のピークがある）場合に特に有用である。このような場合、バイオリン図では複数のピークの位置と大きさが明確に表現されるが、これは箱ひげ図では表現されない。バイオリン図の内部には平均（または中央値）と四分位範囲が描かれる。特にサンプル数があまり多くない場合には、すべてのサンプルデータが点や線として描かれる場合もある。
#
# 箱ひげ図よりも多くの情報が含まれるものの、バイオリン図はよりマイナーである点が欠点である。知名度が低いため、バイオリン図を知らない人にとっては意味が理解しづらい。このような場合、より分かりやすい代替図としてはヒストグラムを複数描画するか、カーネル密度を描画することが考えられる。
# boxplotは四分位数を見やすい。violinplotは分布を可視化して見やすい。

# %% [markdown]
# ## 【問題7】特徴量間の関係の確認

# %%
#縦軸と横軸に特徴量を１つずつ取り、種類毎に色分けした散布図を作る

import itertools

combinations = list(itertools.combinations(df.columns[:4] , 2))
fig,axes = plt.subplots(6 , figsize=(5,30))
for i , comb in enumerate(combinations):
    axes[i].set_title(comb[0] + "and" + comb[1])
    axes[i].set(xlabel=comb[0] + "[cm]" , ylabel = comb[1] + "[cm]")
    axes[i].scatter(df[df["Species"]==0][comb[0]] ,  df[df["Species"]==1][comb[1]],
                                c = "red" , label = iris.target_names[0])
    axes[i].scatter(df[df["Species"]==1][comb[0]] , df[df["Species"]==1][comb[1]],
                                c = "blue" , label = iris.target_names[1])
    axes[i].scatter(df[df["Species"]==2][comb[0]] , df[df["Species"]==2][comb[1]],
                                c = "green" , label = iris.target_names[2])
    axes[i].legend()
plt.show()

# %%
#全ての組み合わせの散布図を一度に表示させる、散布図行列を作る
import seaborn as sns

sns.pairplot(df , hue = "Species")
# Out:
# /Users/hayashikentaro/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Users/hayashikentaro/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/hayashikentaro/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# ...

# %%
#４つの特徴量に関する相関係数行列を作る
df.iloc[: , :4].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# 相関行列のヒートマップを描く
colormap = plt.cm.RdBu
plt.title("df_corr")
sns.heatmap(df.iloc[: , :4].corr(), annot=True , cmap=colormap,);

# %% [markdown]
# # 【問題8】可視化したグラフや表の結果の説明

# %% [markdown]
# 相関行列のヒートマップを見て花弁の長さと花弁の幅は0.96と高い相関性を持つことが読み取れる
# 相関図からがく片の長さと花弁の長さ、太さも0.8以上の相関性を持つことが読み取れる
# 箱ひげ図、バイオリン図からがく片の長さ、花弁の長さ、花弁の幅はsetosa<virgicolr<virgnicaの順に長くなることが読み取れるが、がく片の幅はsetosaが高い数値を出していることからsetosaはがく片が短く、幅が太い花であることが推測できる
